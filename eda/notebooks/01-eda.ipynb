# %% [markdown]
# # 01 - Exploratory Data Analysis (EDA)
#
# This notebook demonstrates a basic EDA workflow using the helper utilities in `src/eda_utils.py`.
#
# Instructions:
# 1. Put your dataset CSV into `eda/data/` (for example `mydata.csv`).
# 2. Update the `DATA_PATH` variable below and run the cells.

# %%
# Basic imports
from src.eda_utils import load_csv, profile_summary, plot_missing_values, plot_correlation_heatmap, plot_target_distribution

# Update path to your CSV file in eda/data/
DATA_PATH = '../data/mydata.csv'

# Load data
df = load_csv(DATA_PATH)
df.head()
